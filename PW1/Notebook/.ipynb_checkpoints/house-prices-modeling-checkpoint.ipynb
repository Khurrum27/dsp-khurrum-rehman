# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error

# %%
train_df = pd.read_csv(r"E:\Python tasks\dsp-khurrum-rehman\PW1\data\train.csv")
test_df = pd.read_csv(r"E:\Python tasks\dsp-khurrum-rehman\PW1\data\test.csv")

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
selected_features = ['LotArea', 'GrLivArea', 'MSZoning', 'Street']
target = 'SalePrice'

# %%
train_clean = train_df[selected_features + [target]].dropna()

# %%
train_clean = train_df[selected_features + [target]].dropna(subset=[target])

# %%
X = train_clean[selected_features]
y = train_clean[target]

# %%
if X.isnull().sum().any():
    print("Features contain NaN values, imputing...")
    imputer = SimpleImputer(strategy='mean')
    X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

if y.isnull().sum() > 0:
    print("Target contains NaN values, imputing...")
    y = y.fillna(y.mean())  # Impute target with mean if any NaN values

# %%
categorical_features = ['MSZoning', 'Street']
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
X_encoded = encoder.fit_transform(X[categorical_features])

# %%
X_encoded_df = pd.DataFrame(X_encoded, columns=encoder.get_feature_names_out(categorical_features))

# %%
continuous_features = ['LotArea', 'GrLivArea']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[continuous_features])

# %%
X_scaled_df = pd.DataFrame(X_scaled, columns=continuous_features)

# %%
X_final = pd.concat([X_scaled_df, X_encoded_df], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_log_error
import numpy as np

def compute_rmsle(y_test, y_pred, precision=4):
    # Ensure no NaN or infinite values in y_pred and y_test
    y_pred = np.nan_to_num(y_pred, nan=np.nanmean(y_pred))  # Replace NaNs in predictions with the mean value
    y_test = np.nan_to_num(y_test, nan=np.nanmean(y_test))  # Replace NaNs in actual values with the mean value
    
    # Clip negative or zero values to a small positive number
    y_test = np.clip(y_test, a_min=1e-5, a_max=None)
    y_pred = np.clip(y_pred, a_min=1e-5, a_max=None)

    # Apply log1p safely
    y_test_log = np.log1p(y_test)  # log(1 + y_test)
    y_pred_log = np.log1p(y_pred)  # log(1 + y_pred)
    
    # Compute RMSLE
    rmsle = np.sqrt(mean_squared_log_error(y_test_log, y_pred_log))
    return round(rmsle, precision)

# Example usage (replace y_test and y_pred with your actual values):
rmsle_score = compute_rmsle(y_test, y_pred)
print(f'RMSLE Score: {rmsle_score}')
# Out:
# RMSLE Score: 0.1444

# %%
rmsle_score = compute_rmsle(y_test, y_pred)
print(f'RMSLE Score: {rmsle_score}')
# Out:
# RMSLE Score: 0.1444

# %%
y_test_clean = np.maximum(y_test, 0)  # Ensures no negative values
y_pred_clean = np.maximum(y_pred, 0)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x=y_test_clean, y=y_pred_clean)
plt.title("Actual vs Predicted (Original Values)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.plot([min(y_test_clean), max(y_test_clean)], [min(y_test_clean), max(y_test_clean)], 'r--', lw=2)  # Diagonal line for perfect predictions

# %%
plt.subplot(1, 2, 2)
sns.scatterplot(x=np.log1p(y_test_clean), y=np.log1p(y_pred_clean))
plt.title("Log-transformed Actual vs Predicted")
plt.xlabel("Log(1 + Actual Values)")
plt.ylabel("Log(1 + Predicted Values)")
plt.plot([min(np.log1p(y_test_clean)), max(np.log1p(y_test_clean))], 
         [min(np.log1p(y_test_clean)), max(np.log1p(y_test_clean))], 'r--', lw=2)  # Diagonal line for perfect predictions

# %%
plt.figure(figsize=(10, 6))

# %%
x = np.arange(len(y_test_log))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 x = np.arange(len(y_test_log))
#
# NameError: name 'y_test_log' is not defined
